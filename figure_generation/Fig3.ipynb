# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# T2T
# list of matplotlib colors: https://matplotlib.org/stable/gallery/color/named_colors.html
wholecell_color = "#990000"
singlenuc_color = "#038a80"

# %%
f1locs = {}
# this is TEsingle at locus level
f1locs['TEsingle'] = {'total':{0.2:0.861181820534397,0.4:0.857928322195307}, 
                   'genes':{0.2:0.868054483849122,0.4:0.864915075600161}, 
                   'tes':{0.2:0.737517249625424,0.4:0.727563256360327}}

# this is starsoloTE EM at locus level
f1locs['STARsolo-TE'] = {'total':{0.2:0.794340065367746,0.4:0.793408189883712}, 
                      'genes':{0.2:0.810918605225637,0.4:0.809415148873456}, 
                      'tes':{0.2:0.511928007358801,0.4:0.510835351906998}}

# %%
f1s = {}
# this is TEsingle at subfam level
f1s['TEsingle'] = {'total':{0.2:0.866512417409857,0.4:0.863411586883185}, 
                   'genes':{0.2:0.868054483849122, 0.4:0.864915075600161}, 
                   'tes':{0.2:0.753288005241192, 0.4:0.745087109426466}}

# this is starsoloTE EM at subfam level
f1s['STARsolo-TE'] = {'total':{0.2:0.804333327479342, 0.4:0.802986144661136}, 
                      'genes':{0.2:0.810918605225637, 0.4:0.809415148873456}, 
                      'tes':{0.2:0.429148009297857, 0.4:0.415135097124234}}

f1s['Cellranger-TE'] = {'total':{0.2:0.781382817436615,0.4:0.720328272416686}, 
                        'genes':{0.2:0.791607167509554,0.4:0.732781825994012}, 
                        'tes':{0.2:0.342402957825863,0.4:0.244180457852816}}

# this is soloTE at the subfamily level
f1s['soloTE'] = {'total':{0.2:0.923380800728098,0.4:0.920886595740367}, 
                 'genes':{0.2:0.936703517320694,0.4:0.935477023548087}, 
                 'tes':{0.2:0.336669468393516,0.4:0.287245951693941}}

f1s['scTE'] = {'total':{0.2:0.653731034765393,0.4:0.545422927942676}, 
               'genes':{0.2:0.658919628678201,0.4:0.549473106292295}, 
               'tes':{0.2:0.123753343800884,0.4:0.12133310873531}}

# %%
raws = {'loc':{},'sub':{}}
raws['loc']['TEsingle'] = {'tot':{'accurate':{0.2:26539249,0.4:28076265}, 
                                  'overcount':{0.2:321598,0.4:356543}, 
                                  'undercount':{0.2:2580278,0.4:2868236}, 
                                  'false_pos':{0.2:1150686,0.4:1184394}, 
                                  'false_neg':{0.2:1601549,0.4:1664825}},
                           'gen':{'accurate':{0.2:25342628,0.4:26865109}, 
                                  'overcount':{0.2:264081,0.4:291053}, 
                                  'undercount':{0.2:2475296,0.4:2755529}, 
                                  'false_pos':{0.2:1075441,0.4:1104469}, 
                                  'false_neg':{0.2:1150036,0.4:1194107}},
                           'tes':{'accurate':{0.2:1196621,0.4:1211156}, 
                                  'overcount':{0.2:57517,0.4:65490}, 
                                  'undercount':{0.2:104982,0.4:112707}, 
                                  'false_pos':{0.2:75245,0.4:79925}, 
                                  'false_neg':{0.2:451513,0.4:470718}}}

raws['loc']['STARsolo-TE'] = {'tot':{'accurate':{0.2:21694604,0.4:23015374}, 
                                     'overcount':{0.2:238979,0.4:264825}, 
                                     'undercount':{0.2:944397,0.4:1011321}, 
                                     'false_pos':{0.2:702309,0.4:759088}, 
                                     'false_neg':{0.2:8164694,0.4:8674349}},
                              'gen':{'accurate':{0.2:20919352,0.4:22220953}, 
                                     'overcount':{0.2:235195,0.4:259879}, 
                                     'undercount':{0.2:647934,0.4:712299}, 
                                     'false_pos':{0.2:559687,0.4:607266}, 
                                     'false_neg':{0.2:7429560,0.4:7912667}},
                              'tes':{'accurate':{0.2:775252,0.4:794421}, 
                                     'overcount':{0.2:3784,0.4:4946}, 
                                     'undercount':{0.2:296463,0.4:299022}, 
                                     'false_pos':{0.2:142622,0.4:151822}, 
                                     'false_neg':{0.2:735134,0.4:761682}}}

# %%
raws['sub']['TEsingle'] = {'tot':{'accurate':{0.2:25642150, 0.4:27159177}, 
                                  'overcount':{0.2:266781, 0.4:293794}, 
                                  'undercount':{0.2:2540929, 0.4:2823254}, 
                                  'false_pos':{0.2:1079516, 0.4:1109087}, 
                                  'false_neg':{0.2:1205490, 0.4:1249773}},
                           'gen':{'accurate':{0.2:25342628, 0.4:26865109}, 
                                  'overcount':{0.2:264081, 0.4:291053}, 
                                  'undercount':{0.2:2475296, 0.4:2755529}, 
                                  'false_pos':{0.2:1075441, 0.4:1104469}, 
                                  'false_neg':{0.2:1150036, 0.4:1194107}},
                           'tes':{'accurate':{0.2:299522, 0.4:294068}, 
                                  'overcount':{0.2:2700, 0.4:2741}, 
                                  'undercount':{0.2:65633, 0.4:67725}, 
                                  'false_pos':{0.2:4075, 0.4:4618}, 
                                  'false_neg':{0.2:55454, 0.4:55666}}}

raws['sub']['STARsolo-TE'] = {'tot':{'accurate':{0.2:21113667, 0.4:22409865}, 
                                     'overcount':{0.2:292212, 0.4:322185}, 
                                     'undercount':{0.2:727230, 0.4:789104}, 
                                     'false_pos':{0.2:711335, 0.4:769166}, 
                                     'false_neg':{0.2:7522241, 0.4:8004844}},
                              'gen':{'accurate':{0.2:20919352, 0.4:22220953}, 
                                     'overcount':{0.2:235195, 0.4:259879}, 
                                     'undercount':{0.2:647934, 0.4:712299}, 
                                     'false_pos':{0.2:559687, 0.4:607266}, 
                                     'false_neg':{0.2:7429560, 0.4:7912667}},
                              'tes':{'accurate':{0.2:194315, 0.4:188912}, 
                                     'overcount':{0.2:57017, 0.4:62306}, 
                                     'undercount':{0.2:79296, 0.4:76805}, 
                                     'false_pos':{0.2:151648, 0.4:161900}, 
                                     'false_neg':{0.2:92681, 0.4:92177}}}

# %%
raws['sub']['Cellranger-TE'] = {'tot':{'accurate':{0.2:22414374, 0.4:21991629}, 
                                  'overcount':{0.2:156799, 0.4:195548}, 
                                  'undercount':{0.2:4554981, 0.4:6462953}, 
                                  'false_pos':{0.2:589540, 0.4:883891}, 
                                  'false_neg':{0.2:2529196, 0.4:2875868}},
                           'gen':{'accurate':{0.2:22190815, 0.4:21801619}, 
                                  'overcount':{0.2:9156, 0.4:13769}, 
                                  'undercount':{0.2:4513363, 0.4:6423152}, 
                                  'false_pos':{0.2:119845, 0.4:159373}, 
                                  'false_neg':{0.2:2518707, 0.4:2867258}},
                           'tes':{'accurate':{0.2:223559, 0.4:190010}, 
                                  'overcount':{0.2:147643, 0.4:181779}, 
                                  'undercount':{0.2:41618, 0.4:39801}, 
                                  'false_pos':{0.2:469695, 0.4:724518}, 
                                  'false_neg':{0.2:10489, 0.4:8610}}}

raws['sub']['soloTE'] = {'tot':{'accurate':{0.2:26990545, 0.4:28635099}, 
                                  'overcount':{0.2:212517, 0.4:232810}, 
                                  'undercount':{0.2:833216, 0.4:919251}, 
                                  'false_pos':{0.2:768641, 0.4:877125}, 
                                  'false_neg':{0.2:1619072, 0.4:1738838}},
                           'gen':{'accurate':{0.2:26772045, 0.4:28434058}, 
                                  'overcount':{0.2:68409, 0.4:70390}, 
                                  'undercount':{0.2:801802, 0.4:889534}, 
                                  'false_pos':{0.2:287963, 0.4:290720}, 
                                  'false_neg':{0.2:1589785, 0.4:1711816}},
                           'tes':{'accurate':{0.2:218500, 0.4:201041}, 
                                  'overcount':{0.2:144108, 0.4:162420}, 
                                  'undercount':{0.2:31414, 0.4:29717}, 
                                  'false_pos':{0.2:480678, 0.4:586405}, 
                                  'false_neg':{0.2:29287, 0.4:27022}}}

raws['sub']['scTE'] = {'tot':{'accurate':{0.2:18551780, 0.4:16087024}, 
                                  'overcount':{0.2:584394, 0.4:538968}, 
                                  'undercount':{0.2:4916735, 0.4:7755702}, 
                                  'false_pos':{0.2:3048355, 0.4:3081482}, 
                                  'false_neg':{0.2:5602441, 0.4:7144304}},
                           'gen':{'accurate':{0.2:18517731, 0.4:16053170}, 
                                  'overcount':{0.2:581077, 0.4:534581}, 
                                  'undercount':{0.2:4853429, 0.4:7690637}, 
                                  'false_pos':{0.2:3022064, 0.4:3046954}, 
                                  'false_neg':{0.2:5279804, 0.4:6827410}},
                           'tes':{'accurate':{0.2:34049, 0.4:33854}, 
                                  'overcount':{0.2:3317, 0.4:4387}, 
                                  'undercount':{0.2:63306, 0.4:65065}, 
                                  'false_pos':{0.2:26291, 0.4:34528}, 
                                  'false_neg':{0.2:322637, 0.4:316894}}}

# %%
subf_algs = ['TEsingle', 'STARsolo-TE', 'Cellranger-TE', 'soloTE', 'scTE']
loc_algs = ['TEsingle', 'STARsolo-TE']
subf_labels = ['TEsingle *', 'STARsolo-TE *', 'Cellranger-TE', 'soloTE *', 'scTE']

# %%
tots = [[],[]]
gens = [[],[]]
tes = [[],[]]

for alg in subf_algs:
    tots[0].append(f1s[alg]['total'][0.2])
    tots[1].append(f1s[alg]['total'][0.4])
    
    gens[0].append(f1s[alg]['genes'][0.2])
    gens[1].append(f1s[alg]['genes'][0.4])
    
    tes[0].append(f1s[alg]['tes'][0.2])
    tes[1].append(f1s[alg]['tes'][0.4])

# %%
plt.figure(figsize=(9,6))
num = len(subf_algs)
baseline = np.zeros(num)

plt.hlines(gens[0][0], -2,10, alpha=0.5, color='gray', linestyle='--', zorder=1)

plt.bar(np.arange(num)-np.ones(num)*0.13, gens[0], align = 'center', width = 0.25, bottom=baseline, color=wholecell_color, label='whole cell')
plt.bar(np.arange(num)+np.ones(num)*0.13, gens[1], align = 'center', width = 0.25, bottom=baseline, color=singlenuc_color, label='single\nnucleus')

plt.xticks(np.arange(num), subf_algs, rotation='vertical')


plt.legend(loc='upper right', prop={'size':12})
plt.rcParams.update({'font.size': 16})
plt.grid(axis='y', alpha=0.75, color='white')
plt.ylim(0,1)
plt.xlim(-0.5,4.5)
plt.ylabel('F1 score')
plt.title('Accuracy on genes')
#plt.savefig('25.06.05_t2t_gen_F1.png', bbox_inches="tight", pad_inches=0.2)
plt.show()

# %%
plt.figure(figsize=(9,6))
num = len(subf_labels)
baseline = np.zeros(num)

plt.hlines(tes[0][0], -2,10, alpha=0.5, color='gray', linestyle='--', zorder=1)

plt.bar(np.arange(num)-np.ones(num)*0.13, tes[0], align = 'center', width = 0.25, bottom=baseline, color=wholecell_color, label='whole cell')
plt.bar(np.arange(num)+np.ones(num)*0.13, tes[1], align = 'center', width = 0.25, bottom=baseline, color=singlenuc_color, label='single\nnucleus')

plt.xticks(np.arange(num), subf_labels, rotation='vertical')


plt.legend(loc='upper right', prop={'size':12})
plt.rcParams.update({'font.size': 16})
plt.grid(axis='y', alpha=0.75, color='white')
plt.ylim(0,1)
plt.xlim(-0.5,4.5)
plt.ylabel('F1 score')
plt.title('Accuracy on TEs')
#plt.savefig('25.06.05_t2t_tes_F1.png', bbox_inches="tight", pad_inches=0.2)
plt.show()

# %%
plt.figure(figsize=(4,6))
loc_algs = ['TEsingle', 'STARsolo-TE']
num = len(loc_algs)
baseline = np.zeros(num)

loc_tes = [[],[]]

for alg in loc_algs:
    loc_tes[0].append(f1locs[alg]['tes'][0.2])
    loc_tes[1].append(f1locs[alg]['tes'][0.4])

plt.hlines(loc_tes[0][0], -2,10, alpha=0.5, color='gray', linestyle='--', zorder=1)

plt.bar(np.arange(num)-np.ones(num)*0.13, loc_tes[0], align = 'center', width = 0.25, bottom=baseline, color=wholecell_color, label='whole cell')
plt.bar(np.arange(num)+np.ones(num)*0.13, loc_tes[1], align = 'center', width = 0.25, bottom=baseline, color=singlenuc_color, label='single\nnucleus')

plt.xticks(np.arange(num), loc_algs, rotation='vertical')


plt.legend(loc='upper right', prop={'size':12})
plt.rcParams.update({'font.size': 16})
plt.grid(axis='y', alpha=0.75, color='white')
plt.ylim(0,1)
plt.xlim(-0.5,1.5)
plt.ylabel('F1 score')
plt.title('Accuracy on TEs')
#plt.savefig('25.06.05_t2t_tes_locus_F1.png', bbox_inches="tight", pad_inches=0.2)
plt.show()

# %%
fptots = [[],[]]
fpgens = [[],[]]
fptes = [[],[]]

fntots = [[],[]]
fngens = [[],[]]
fntes = [[],[]]

for alg in subf_algs:
    fptots[0].append(raws['sub'][alg]['tot']['false_pos'][0.2])
    fptots[1].append(raws['sub'][alg]['tot']['false_pos'][0.4])
    
    fpgens[0].append(raws['sub'][alg]['gen']['false_pos'][0.2])
    fpgens[1].append(raws['sub'][alg]['gen']['false_pos'][0.4])
    
    fptes[0].append(raws['sub'][alg]['tes']['false_pos'][0.2])
    fptes[1].append(raws['sub'][alg]['tes']['false_pos'][0.4])

    fntots[0].append(raws['sub'][alg]['tot']['false_neg'][0.2])
    fntots[1].append(raws['sub'][alg]['tot']['false_neg'][0.4])
    
    fngens[0].append(raws['sub'][alg]['gen']['false_neg'][0.2])
    fngens[1].append(raws['sub'][alg]['gen']['false_neg'][0.4])
    
    fntes[0].append(raws['sub'][alg]['tes']['false_neg'][0.2])
    fntes[1].append(raws['sub'][alg]['tes']['false_neg'][0.4])

# %%
falseneg_color = "black"
falsepos_color = "white"

# %%
plt.figure(figsize=(9,6))
xs = []
cond_counter = 1
cats = ['false negatives', 'false positives']
state = 'gen'

offset = {0.2:-0.1,0.4:0.1}
wholecell = 0.2
singlenuc = 0.4

labels = True

for alg in subf_algs:
    xs.append(cond_counter)
    wcfn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    wcfp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    snfn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)
    snfp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)

    wcfnn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    wcfpp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)
    snfnn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    snfpp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)

    cond_counter += 1

plt.xticks(xs, subf_algs, rotation='vertical')

plt.legend(((wcfn_handle, wcfnn_handle), (wcfp_handle, wcfpp_handle), (snfn_handle, snfnn_handle), (snfp_handle, snfpp_handle)), ("whole cell\nfalse negative", "whole cell\nfalse positive", "single nuc\nfalse negative", "single nuc\nfalse positive"), loc='upper right', prop={'size':12}, bbox_to_anchor=(1.3, 1), borderaxespad=0.)


plt.title('False positives and negatives on genes')
plt.grid(axis='y', alpha=0.75, color='white')
#plt.savefig('25.06.05_t2t_fpfn_gen.png', bbox_inches="tight", pad_inches=0.2)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
xs = []
cond_counter = 1
cats = ['false negatives', 'false positives']
state = 'tes'

offset = {0.2:-0.1,0.4:0.1}
wholecell = 0.2
singlenuc = 0.4

labels = True

for alg in subf_algs:
    xs.append(cond_counter)
    wcfn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    wcfp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    snfn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)
    snfp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)

    wcfnn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    wcfpp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)
    snfnn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    snfpp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)

    cond_counter += 1

plt.xticks(xs, subf_labels, rotation='vertical')

plt.legend(((wcfn_handle, wcfnn_handle), (wcfp_handle, wcfpp_handle), (snfn_handle, snfnn_handle), (snfp_handle, snfpp_handle)), ("whole cell\nfalse negative", "whole cell\nfalse positive", "single nuc\nfalse negative", "single nuc\nfalse positive"), loc='upper right', prop={'size':12}, bbox_to_anchor=(1.3, 1), borderaxespad=0.)

plt.title('False positives and negatives on TEs')
plt.grid(axis='y', alpha=0.75, color='white')
plt.ylim([0,750000])
#plt.savefig('25.06.05_t2t_fpfn_tes.png', bbox_inches="tight", pad_inches=0.2)
plt.show()

# %%
plt.figure(figsize=(3,6))
plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0))
xs = []
cond_counter = 1
cats = ['false negatives', 'false positives']
state = 'tes'

offset = {0.2:-0.1,0.4:0.1}
wholecell = 0.2
singlenuc = 0.4

labels = True

for alg in loc_algs:
    xs.append(cond_counter)
    wcfn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    wcfp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=wholecell_color)
    snfn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)
    snfp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=singlenuc_color)

    wcfnn_handle=plt.bar([cond_counter+offset[wholecell]-0.05], raws['sub'][alg][state]['false_neg'][wholecell], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    wcfpp_handle=plt.bar([cond_counter+offset[wholecell]+0.05], raws['sub'][alg][state]['false_pos'][wholecell], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)
    snfnn_handle=plt.bar([cond_counter+offset[singlenuc]-0.05], raws['sub'][alg][state]['false_neg'][singlenuc], align='center', width=0.1, bottom=0, color=falseneg_color, alpha=0.2)
    snfpp_handle=plt.bar([cond_counter+offset[singlenuc]+0.05], raws['sub'][alg][state]['false_pos'][singlenuc], align='center', width=0.1, bottom=0, color=falsepos_color, alpha=0.2)

    cond_counter += 1

plt.xticks(xs, loc_algs, rotation='vertical')

plt.legend(((wcfn_handle, wcfnn_handle), (wcfp_handle, wcfpp_handle), (snfn_handle, snfnn_handle), (snfp_handle, snfpp_handle)), ("whole cell\nfalse negative", "whole cell\nfalse positive", "single nuc\nfalse negative", "single nuc\nfalse positive"), loc='upper right', prop={'size':12}, bbox_to_anchor=(1.8, 1), borderaxespad=0.)

plt.title('False positives and negatives on TEs')
plt.grid(axis='y', alpha=0.75, color='white')
plt.ylim([0,750000])
#plt.savefig('25.06.05_t2t_fpfn_loc.png', bbox_inches="tight", pad_inches=0.2)
plt.show()
